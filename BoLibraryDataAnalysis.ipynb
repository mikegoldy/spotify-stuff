# %%
"""
Take a csv of my Bo's music library (1812 songs) and assess key characteristics.
Bo's music will be useful to analyze because he only listens (and is very proud) to 
hip hop/rap music.
"""
# Out:
# '\nTake a csv of my entire music library (1522 songs) and assess key characteristics.\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.plotting.register_matplotlib_converters()
import seaborn as sns
import numpy as np

# %%
spotify_data = pd.read_csv("/Users/michaelgoldfeld/Documents/Python projects/Spotify/playlistBo.csv")
spotify_data.set_index("name",inplace=True, drop=True)
spotify_data.drop(spotify_data.columns[0],axis=1, inplace=True)
spotify_data.head()
# Out:
#                       artist  duration  key  mode  beats  acousticness  \
# name
# So We Can Live      2 Chainz    406373    6     1      4        0.0516
# Mainstream Ratchet  2 Chainz    238187    5     1      4        0.5890
# Feds Watching       2 Chainz    247013    7     1      4        0.0476
# I Do It             2 Chainz    373693   11     0      4        0.1810
# Saturday Night      2 Chainz    271187    0     0      4        0.4520
#
#                     danceability  energy  instrumentalness  liveness  \
# name
# So We Can Live             0.452   0.717          0.000000    0.0778
# Mainstream Ratchet         0.733   0.549          0.000075    0.2550
# Feds Watching              0.790   0.875          0.000000    0.3120
# I Do It                    0.581   0.716          0.000000    0.2010
# Saturday Night             0.644   0.805          0.000010    0.1100
#
#                     loudness  speechiness  valence    tempo  popularity  \
# name
# So We Can Live        -7.151       0.3240    0.458   78.306          11
# Mainstream Ratchet    -5.605       0.0858    0.246  121.982          11
# Feds Watching         -6.550       0.0910    0.759  139.985          24
# I Do It               -4.486       0.1860    0.597  145.378          20
# Saturday Night        -4.513       0.0975    0.461  115.915          48
#
#                                                      URI
# name
# So We Can Live      spotify:track:5qtYOifRgh6UC4Muyp5XZv
# Mainstream Ratchet  spotify:track:1S5Aw8EVdP8Uqsz6H1MBR0
# Feds Watching       spotify:track:7cDzi0VONMrZoNUhh5OGFK
# I Do It             spotify:track:3x9j7V2GEuCHBm32nUrzWl
# Saturday Night      spotify:track:5zlSTZhZq6rXL4Xn2PBayO

# %%
sns.distplot(a=spotify_data["valence"], kde=False) # Negativity - positivity of music (from 0-1)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
spotify_data["valence"].mean()
# Out:
# 0.4274724613686529

# %%
sns.distplot(a=spotify_data["danceability"])

# %%
sns.distplot(a=spotify_data["energy"])

# %%
sns.distplot(a=spotify_data["popularity"])

# %%
sns.distplot(a=spotify_data["acousticness"]) #How much does a song rely on real instruments
# 0 for electronic 1 for pure instruments

# %%
sns.distplot(a=spotify_data["loudness"])

# %%
sns.distplot(a=spotify_data["instrumentalness"]) #Likelihood of vocals in the music

# %%
sns.distplot(a=spotify_data["speechiness"]) # I don't like songs with a lot of words.

# %%
sns.distplot(a=spotify_data["tempo"])

# %%
spotify_data["tempo"].mean()
# Out:
# 122.55487086092732

# %%
spotify_data_mean = spotify_data.mean()
spotify_data_mean.drop(["duration", "tempo", "popularity", "key", "beats", "loudness"], inplace=True)
spotify_data_mean.plot(kind="bar")
