# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.plotting.register_matplotlib_converters()
import seaborn as sns
import numpy as np

# %%
spotify_data = pd.read_csv("/Users/michaelgoldfeld/Documents/Python projects/Spotify/playlistInfoPopular.csv")
spotify_data.set_index("name",inplace=True, drop=True)
spotify_data.drop(spotify_data.columns[0],axis=1, inplace=True)
spotify_data.head()
# Out:
#                  artist  duration  key  mode  beats  acousticness  \
# name
# The Box     Roddy Ricch    196653   10     0      4        0.1040
# ROXANNE  Arizona Zervas    163636    6     0      5        0.0522
# Circles     Post Malone    215280    0     1      4        0.1920
# BOP              DaBaby    159715   11     1      4        0.1890
# Falling   Trevor Daniel    159382   10     0      4        0.1230
#
#          danceability  energy  instrumentalness  liveness  loudness  \
# name
# The Box         0.896   0.586           0.00000    0.7900    -6.687
# ROXANNE         0.621   0.601           0.00000    0.4600    -5.616
# Circles         0.695   0.762           0.00244    0.0863    -3.497
# BOP             0.769   0.787           0.00000    0.1290    -3.909
# Falling         0.784   0.430           0.00000    0.0887    -8.756
#
#          speechiness  valence    tempo  popularity  \
# name
# The Box       0.0559    0.642  116.971          92
# ROXANNE       0.1480    0.457  116.735          99
# Circles       0.0395    0.553  120.042          98
# BOP           0.3670    0.836  126.770          92
# Falling       0.0364    0.236  127.087          97
#
#                                           URI
# name
# The Box  spotify:track:0nbXyq5TXYPCO7pr3N8S4I
# ROXANNE  spotify:track:696DnlkuDOXcMAnKlTgXXK
# Circles  spotify:track:21jGcNKet2qwijlDFuPiPb
# BOP      spotify:track:6Ozh9Ok6h4Oi1wUSLtBseN
# Falling  spotify:track:4TnjEaWOeW0eKTKIEvJyCa

# %%
spotify_data_mean = spotify_data.mean()
spotify_data_mean.drop(["duration", "tempo", "popularity", "key", "beats", "loudness"], inplace=True)
spotify_data_mean.plot(kind="bar")
