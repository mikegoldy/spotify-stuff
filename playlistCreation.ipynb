# %%
"""Create Several Playlists based on certain metrics such as:
Workout Playlist (High Energy Songs (>.75) and above average danceability songs (>.5))
Feel Good Playlist (High Valence Songs (>.75))
Dancing Music (High Danceability Songs (>.75))

And evaluate these songs based off personal experience to see how this experiment unfolds
"""

# %%
import pandas as pd
import spotipy
import SpotifyCred

# %%
spotify_data = pd.read_csv("/Users/michaelgoldfeld/Documents/Python projects/Spotify/playlistInfo.csv")
spotify_data.set_index("name",inplace=True, drop=True)
spotify_data.drop(spotify_data.columns[0],axis=1, inplace=True)
spotify_data.head()
# Out:
#                                           artist  duration  key  mode  beats  \
# name
# A) the Wonder (Album Version)        Sonic Youth    255680    0     1      4
# a&t                                    21 Savage    211588    5     1      4
# A$AP Forever                          A$AP Rocky    233061   10     0      4
# About A Girl                             Nirvana    166640   11     0      4
# Abracadabra                    Steve Miller Band    308373    9     0      4
#
#                                acousticness  danceability  energy  \
# name
# A) the Wonder (Album Version)      0.018000         0.103   0.959
# a&t                                0.001690         0.924   0.567
# A$AP Forever                       0.224000         0.469   0.780
# About A Girl                       0.000019         0.409   0.932
# Abracadabra                        0.074900         0.791   0.535
#
#                                instrumentalness  liveness  loudness  \
# name
# A) the Wonder (Album Version)          0.446000    0.3700    -4.408
# a&t                                    0.000000    0.0898    -5.009
# A$AP Forever                           0.000000    0.1300    -6.490
# About A Girl                           0.000002    0.3100    -4.538
# Abracadabra                            0.000002    0.1560   -13.261
#
#                                speechiness  valence    tempo  popularity  \
# name
# A) the Wonder (Album Version)       0.0936    0.222  177.115          24
# a&t                                 0.0964    0.827  146.975          57
# A$AP Forever                        0.1220    0.444  125.999          68
# About A Girl                        0.0339    0.591  131.761          68
# Abracadabra                         0.0355    0.963  127.488          53
#
#                                                                 URI
# name
# A) the Wonder (Album Version)  spotify:track:1WvkytBDFejuo8no8Ro0O7
# a&t                            spotify:track:6ho88pvz4c8WCSFbdVXNia
# A$AP Forever                   spotify:track:1YmF9PvLhIISIANoMLIYGq
# About A Girl                   spotify:track:55yvzYuvJYG2RUEnMK78tr
# Abracadabra                    spotify:track:2E2ZVy2fxslpAUgbb4zu84

# %%
def toPlaylist(playlistName, songs):
    """
    Parameters:
    playlistName - Desired name for playlist
    songs- pandas dataframe
    """
    sp = SpotifyCred.spotifyCreds()
    user = sp.current_user()["id"]
    id = []
    playlist = sp.user_playlist_create(user, playlistName)
    for index, row in songs.iterrows():
        trackId = row['URI']
        id.append(trackId)
        sp.user_playlist_add_tracks(user,playlist_id=playlist['id'], tracks=id)
        id =[]

# %%
high_energy = spotify_data[(spotify_data["energy"] >= .75) & (spotify_data["danceability"] >= .5)]

# %%
high_energy.head()
# Out:
#                                                                artist  \
# name
# Addiction                                                  Kanye West
# Aftershock (feat. Jacquie)                                  Cash Cash
# Ai Se Eu Te Pego - Ao Vivo                                Michel Teló
# Ain't No Rest for the Wicked                        Cage The Elephant
# Airplanes, Pt. II (feat. Eminem & Hayley Willia...              B.o.B
#
#                                                     duration  key  mode  \
# name
# Addiction                                             267067    1     0
# Aftershock (feat. Jacquie)                            206320    8     1
# Ai Se Eu Te Pego - Ao Vivo                            170493   11     1
# Ain't No Rest for the Wicked                          175493    0     1
# Airplanes, Pt. II (feat. Eminem & Hayley Willia...    319293    6     0
#
#                                                     beats  acousticness  \
# name
# Addiction                                               4       0.18500
# Aftershock (feat. Jacquie)                              4       0.05200
# Ai Se Eu Te Pego - Ao Vivo                              4       0.22200
# Ain't No Rest for the Wicked                            4       0.04380
# Airplanes, Pt. II (feat. Eminem & Hayley Willia...      4       0.00325
#
#                                                     danceability  energy  \
# name
# Addiction                                                  0.659   0.756
# Aftershock (feat. Jacquie)                                 0.544   0.811
# Ai Se Eu Te Pego - Ao Vivo                                 0.650   0.947
# Ain't No Rest for the Wicked                               0.634   0.849
# Airplanes, Pt. II (feat. Eminem & Hayley Willia...         0.665   0.878
#
#                                                     instrumentalness  \
# name
# Addiction                                                        0.0
# Aftershock (feat. Jacquie)                                       0.0
# Ai Se Eu Te Pego - Ao Vivo                                       0.0
# Ain't No Rest for the Wicked                                     0.0
# Airplanes, Pt. II (feat. Eminem & Hayley Willia...               0.0
#
#                                                     liveness  loudness  \
# name
# Addiction                                             0.2520    -8.318
# Aftershock (feat. Jacquie)                            0.1210    -2.271
# Ai Se Eu Te Pego - Ao Vivo                            0.9790    -5.326
# Ain't No Rest for the Wicked                          0.3630    -7.075
# Airplanes, Pt. II (feat. Eminem & Hayley Willia...    0.0663    -4.745
#
#                                                     speechiness  valence  \
# name
# Addiction                                                0.1650    0.551
# Aftershock (feat. Jacquie)                               0.0515    0.188
# Ai Se Eu Te Pego - Ao Vivo                               0.0717    0.694
# Ain't No Rest for the Wicked                             0.1050    0.919
# Airplanes, Pt. II (feat. Eminem & Hayley Willia...       0.2060    0.394
#
#                                                       tempo  popularity  \
# name
# Addiction                                           115.389          52
# Aftershock (feat. Jacquie)                          129.011          47
# Ai Se Eu Te Pego - Ao Vivo                           96.035          64
# Ain't No Rest for the Wicked                        156.004          73
# Airplanes, Pt. II (feat. Eminem & Hayley Willia...   93.047          60
#
#                                                                                      URI
# name
# Addiction                                           spotify:track:5VzeI5JM2y9t21JwrWAnkH
# Aftershock (feat. Jacquie)                          spotify:track:1s82u8aaERDyKAyt2vyhQr
# Ai Se Eu Te Pego - Ao Vivo                          spotify:track:46aIq2GKW7Vr6i4g2Vvycd
# Ain't No Rest for the Wicked                        spotify:track:3Pzh926pXggbMe2ZpXyMV7
# Airplanes, Pt. II (feat. Eminem & Hayley Willia...  spotify:track:2bnDTGikdoO8CwzlAPyBHR

# %%
high_energy.to_csv("highEnergy.csv")

# %%
toPlaylist("Workout Mix", high_energy)

# %%
high_valence = spotify_data[spotify_data["valence"] >= .75]

# %%
toPlaylist("Feel Good Mix", high_valence)

# %%
dance_music = spotify_data[spotify_data["danceability"] >= .75]

# %%
toPlaylist("Dancing Music", dance_music)
